# %%
from simulator import run_master_simulator
from evaluator import run_evaluation

policy_text = "Government is planning to impose a hefty fine on everyone who has scored below 90% in their 10th class, to motivate them to study more "

# %%
run_master_simulator(policy_text)
# Out:
# ...
# MASTER SIMULATOR GRAPH - STARTING
# ...
# Simulation ID: sim_c23a699f3d1a4b91
# Timestamp: 2026-04-16T21:17:53.529967
# Policy: Government is planning to impose a hefty fine on everyone who has scored below 90% in their 10th cla...
# ...
# NODE 1: SCREENING AGENTS
# ...
#
# 1. Vectorizing policy text...
# ✓ Policy vector obtained: {'tax': 0.281, 'cost_of_living': 0.021, 'employment': 0.032, 'wealth': 0.051, 'transport': 0.009, 'internet': 0.005, 'safety': 0.015, 'environment': 0.002, 'education': 0.947, 'health': 0.011, 'leisure': 0.017, 'welfare': 0.062, 'social_affinity': 0.041, 'civic_engagement': 0.008}
#
# 2. Screening exactly 5 agents based on policy vector...
# ✓ Screened 5 agents: ['ag61758493627581946', 'ag85473198264571938', 'ag54638927165482935', 'ag72985641734958267', 'ag17428934659271185']
#
# 3. Generating agent details string...
# ✓ Agent details string generated (length: 7895 chars)
#
# ...
# NODE 2: EVENT GENERATION
# ...
#
# 1. Initializing LLM for event generation...
# ...

# %%
run_evaluation()
# Out:
# Evaluating 5 reactions parallely...
# Successfully pushed 5 evaluated reactions into the 'evaluations' collection.
