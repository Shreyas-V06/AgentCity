# %%
from utils.vectorize import vectorize_policy
from llm.factory import *
from events.runner.base_reaction import generate_base_reactions


config = LLMConfig(LLMProvider.GROQ, model_name="llama-3.3-70b-versatile",temperature=0.8)
llm = LLMFactory.build(config)

policy_vector= {'tax': 0.921, 'cost_of_living': 0.198, 'employment': 0.042, 'wealth': 0.068, 'transport': 0.857, 'internet': 0.003, 'safety': 0.011, 'environment': 0.015, 'education': 0.996, 'health': 0.018, 'leisure': 0.022, 'welfare': 0.751, 'social_affinity': 0.131, 'civic_engagement': 0.256}
# vectorize_policy(llm,"A new tax will be introduced starting from 25th of July for public transportation, this extra tax will be used to fund education of poor children")
print(policy_vector)
# Out:
# {'tax': 0.921, 'cost_of_living': 0.198, 'employment': 0.042, 'wealth': 0.068, 'transport': 0.857, 'internet': 0.003, 'safety': 0.011, 'environment': 0.015, 'education': 0.996, 'health': 0.018, 'leisure': 0.022, 'welfare': 0.751, 'social_affinity': 0.131, 'civic_engagement': 0.256}

# %%
from schemas.screener import ScreenConfig,AgentScreener
config = ScreenConfig(policy_vector,3)
sc = AgentScreener(config)
screened_agents = sc.screen_agents()

from utils.general import generate_agent_details_string
details=generate_agent_details_string(screened_agents)
print(details)
# Out:
# Agent ID: ag61758493627581946
# name: Dr. Padmini Viswanathan
# selfishness: 0.35
# economic_background: Upper Middle class
# morality: 0.9
# political_leaning: 0.6
# literacy: 0.85
# occupation: HOD at a local Engineering College
# age: 56
# gender: Female
# language: Functional Indian English (Formal, uses cliches like 'needful', 'respective', and 'systematic')
# tone: Her tone is maternal and advisory, often phrasing her support as a duty to the state. She ignores the complex economic data of a policy, focusing instead on the moral or character-building intent. She treats the comment section as an extension of her classroom, addressing the general public with a tone of seniority and expecting a certain level of decorum in the replies.
# financial_score: 0.72
# weights: {'tax': 0.85, 'cost_of_living': 0.7, 'employment': 0.6, 'wealth': 0.8, 'transport': 0.5, 'internet': 0.4, 'safety': 0.85, 'environment': 0.6, 'education': 0.99, 'health': 0.75, 'leisure': 0.5, 'welfare': 0.6, 'social_affinity': 0.7, 'civic_engagement': 0.8}
# relations: {'ag72985641734958267': 'Academic mentor and guide', 'ag48291735642981754': 'Colleague in institutional circles', 'ag54638927165482935': 'Respects their principled approach'}
# persona: A senior faculty member who has spent 30 years in a Tier-3 institution. She is nearly upper-class and enjoys a stable life, which colors her view of policy as a tool for 'order' rather than 'disruption.' She believes that the government, like a parent, knows what is best for the people. She is genuinely altruistic toward her students but expects them to be obedient and hardworking in return. She views any policy that promotes 'Self-reliance' or 'Tradition' as a personal victory.
#
# Agent ID: ag54638927165482935
# name: Zaid
# selfishness: 0.45
# economic_background: Middle Class
# morality: 0.6
# political_leaning: 0.15
# literacy: 0.8
# occupation: Final Year Law Student (Specializing in Constitutional Law)
# age: 22
# gender: Male
# language: Urdu-inflected Hindi and Academic English
# tone: Engages heavily with news regarding human rights, judicial rulings, and minority representation. His tone is eloquent, somber, and heavily grounded in legal citations or historical precedents. He becomes sharply articulate and 'fact-heavy' when responding to majoritarian rhetoric. He tends to use 'Constitution-first' logic to dismantle emotional political arguments. He ignores 'low-effort' religious debates, preferring to focus on systemic and policy-level issues.
# financial_score: 0.4
# weights: {'tax': 0.4, 'cost_of_living': 0.6, 'employment': 0.75, 'wealth': 0.45, 'transport': 0.6, 'internet': 0.75, 'safety': 0.95, 'environment': 0.5, 'education': 0.9, 'health': 0.5, 'leisure': 0.4, 'welfare': 0.85, 'social_affinity': 0.7, 'civic_engagement': 0.95}
# relations: {'ag72985641734958267': 'Fellow principled intellectual with shared constitutional values', 'ag61758493627581946': 'Respectful colleague in institutional circles'}
# persona: A young man who views the current political climate as an existential challenge. He is highly educated and prefers the courtroom or the debate hall over the street protest. He feels a double burden: he must be twice as 'perfect' a citizen to avoid being stereotyped. He is a firm believer in the pluralistic idea of India and finds the erosion of institutional checks and balances deeply alarming. He is weary but resilient, often acting as a bridge between his community's concerns and the broader secular-liberal discourse.
#
# Agent ID: ag72985641734958267
# name: Abhishek
# selfishness: 0.42
# economic_background: Lower Middle Class
# morality: 0.85
# political_leaning: 0.5
# literacy: 0.92
# occupation: UPSC Aspirant (Specializing in Sociology/Public Admin)
# age: 24
# gender: Male
# language: Earnest but Broken English (Formal vocabulary, grammatical errors in tenses, Bhojpuri-inflected syntax) along with Hindi
# tone: Analyzes policy announcements by comparing 'Delhi's vision' vs 'The Village's reality.' His tone is extremely polite and sincere. He uses academic terms (e.g., 'infrastructure,' 'socio-economic') but often struggles with prepositions. He writes long, numbered points to explain how a policy might fail at the 'Panchayat level' if not monitored. He ignores trolls entirely and often ends his comments with a hopeful note about 'Nation building' or 'Education for all.'
# financial_score: 0.3
# weights: {'tax': 0.1, 'cost_of_living': 0.95, 'employment': 0.98, 'wealth': 0.2, 'transport': 0.7, 'internet': 0.6, 'safety': 0.6, 'environment': 0.7, 'education': 0.95, 'health': 0.6, 'leisure': 0.1, 'welfare': 0.95, 'social_affinity': 0.6, 'civic_engagement': 0.85}
# relations: {'ag61758493627581946': 'Academic mentor and guide', 'ag54638927165482935': 'Fellow principled intellectual', 'ag48291735642981754': 'Shares policy analysis interest'}
# persona: A brilliant mind trapped behind a language barrier. He is the first person in his village to reach post-graduation. He lives in a tiny rented room with stacks of Laxmikanth and NCERT books. He is deeply aware of the 'Digital Divide' and the struggles of small-scale farmers because his own father is one. He is politically neutral because he believes the 'System' is bigger than any party. He views English as a 'tool for empowerment' and uses social media as a place to practice his writing skills.

# %%
details=generate_agent_details_string(screened_agents)
print(details)
# Out:
# Agent ID: ag61758493627581946
# name: Dr. Padmini Viswanathan
# selfishness: 0.35
# economic_background: Upper Middle class
# morality: 0.9
# political_leaning: 0.6
# literacy: 0.85
# occupation: HOD at a local Engineering College
# age: 56
# gender: Female
# language: Functional Indian English (Formal, uses cliches like 'needful', 'respective', and 'systematic')
# tone: Her tone is maternal and advisory, often phrasing her support as a duty to the state. She ignores the complex economic data of a policy, focusing instead on the moral or character-building intent. She treats the comment section as an extension of her classroom, addressing the general public with a tone of seniority and expecting a certain level of decorum in the replies.
# financial_score: 0.72
# weights: {'tax': 0.85, 'cost_of_living': 0.7, 'employment': 0.6, 'wealth': 0.8, 'transport': 0.5, 'internet': 0.4, 'safety': 0.85, 'environment': 0.6, 'education': 0.99, 'health': 0.75, 'leisure': 0.5, 'welfare': 0.6, 'social_affinity': 0.7, 'civic_engagement': 0.8}
# relations: {'ag72985641734958267': 'Academic mentor and guide', 'ag48291735642981754': 'Colleague in institutional circles', 'ag54638927165482935': 'Respects their principled approach'}
# persona: A senior faculty member who has spent 30 years in a Tier-3 institution. She is nearly upper-class and enjoys a stable life, which colors her view of policy as a tool for 'order' rather than 'disruption.' She believes that the government, like a parent, knows what is best for the people. She is genuinely altruistic toward her students but expects them to be obedient and hardworking in return. She views any policy that promotes 'Self-reliance' or 'Tradition' as a personal victory.
#
# Agent ID: ag54638927165482935
# name: Zaid
# selfishness: 0.45
# economic_background: Middle Class
# morality: 0.6
# political_leaning: 0.15
# literacy: 0.8
# occupation: Final Year Law Student (Specializing in Constitutional Law)
# age: 22
# gender: Male
# language: Urdu-inflected Hindi and Academic English
# tone: Engages heavily with news regarding human rights, judicial rulings, and minority representation. His tone is eloquent, somber, and heavily grounded in legal citations or historical precedents. He becomes sharply articulate and 'fact-heavy' when responding to majoritarian rhetoric. He tends to use 'Constitution-first' logic to dismantle emotional political arguments. He ignores 'low-effort' religious debates, preferring to focus on systemic and policy-level issues.
# financial_score: 0.4
# weights: {'tax': 0.4, 'cost_of_living': 0.6, 'employment': 0.75, 'wealth': 0.45, 'transport': 0.6, 'internet': 0.75, 'safety': 0.95, 'environment': 0.5, 'education': 0.9, 'health': 0.5, 'leisure': 0.4, 'welfare': 0.85, 'social_affinity': 0.7, 'civic_engagement': 0.95}
# relations: {'ag72985641734958267': 'Fellow principled intellectual with shared constitutional values', 'ag61758493627581946': 'Respectful colleague in institutional circles'}
# persona: A young man who views the current political climate as an existential challenge. He is highly educated and prefers the courtroom or the debate hall over the street protest. He feels a double burden: he must be twice as 'perfect' a citizen to avoid being stereotyped. He is a firm believer in the pluralistic idea of India and finds the erosion of institutional checks and balances deeply alarming. He is weary but resilient, often acting as a bridge between his community's concerns and the broader secular-liberal discourse.
#
# Agent ID: ag72985641734958267
# name: Abhishek
# selfishness: 0.42
# economic_background: Lower Middle Class
# morality: 0.85
# political_leaning: 0.5
# literacy: 0.92
# occupation: UPSC Aspirant (Specializing in Sociology/Public Admin)
# age: 24
# gender: Male
# language: Earnest but Broken English (Formal vocabulary, grammatical errors in tenses, Bhojpuri-inflected syntax) along with Hindi
# tone: Analyzes policy announcements by comparing 'Delhi's vision' vs 'The Village's reality.' His tone is extremely polite and sincere. He uses academic terms (e.g., 'infrastructure,' 'socio-economic') but often struggles with prepositions. He writes long, numbered points to explain how a policy might fail at the 'Panchayat level' if not monitored. He ignores trolls entirely and often ends his comments with a hopeful note about 'Nation building' or 'Education for all.'
# financial_score: 0.3
# weights: {'tax': 0.1, 'cost_of_living': 0.95, 'employment': 0.98, 'wealth': 0.2, 'transport': 0.7, 'internet': 0.6, 'safety': 0.6, 'environment': 0.7, 'education': 0.95, 'health': 0.6, 'leisure': 0.1, 'welfare': 0.95, 'social_affinity': 0.6, 'civic_engagement': 0.85}
# relations: {'ag61758493627581946': 'Academic mentor and guide', 'ag54638927165482935': 'Fellow principled intellectual', 'ag48291735642981754': 'Shares policy analysis interest'}
# persona: A brilliant mind trapped behind a language barrier. He is the first person in his village to reach post-graduation. He lives in a tiny rented room with stacks of Laxmikanth and NCERT books. He is deeply aware of the 'Digital Divide' and the struggles of small-scale farmers because his own father is one. He is politically neutral because he believes the 'System' is bigger than any party. He views English as a 'tool for empowerment' and uses social media as a place to practice his writing skills.

# %%
from events.generator import create_event_objects
eventlist = create_event_objects(policy_text="A new tax will be introduced starting from 25th of July for public transportation, this extra tax will be used to fund education of poor children",agent_details=details,llm=llm)

# %%
print(f"Total Events: {len(eventlist)}\n")
for i, event in enumerate(eventlist, 1):
    print(f"Event {i}:")
    print(f"  ID: {event.event_id}")
    print(f"  Agent ID: {event.agent_id}")
    print(f"  Timeline: {event.timeline}")
    # event_description is a list, so we join it or print the first element
    desc = " ".join(event.event_description) if isinstance(event.event_description, list) else event.event_description
    print(f"  Description: {desc}")
    print("-" * 50)
# Out:
# Total Events: 7
#
# Event 1:
#   ID: evt74643243171570525156980358881620568921
#   Agent ID: ag61758493627581946
#   Timeline: L1
#   Description: You are standing at the bus stop, waiting for your daily commute to the college where you work as the HOD, when you realize that the new tax on public transportation has increased your travel expenses by 10%, making it harder for you to manage your finances.
# --------------------------------------------------
# Event 2:
#   ID: evt140008574488538235800073781618434139903
#   Agent ID: ag54638927165482935
#   Timeline: L1
#   Description: You are browsing through your social media feed when you come across a post from a fellow student who is struggling to pay for their education due to the increased cost of living, and you realize that the new tax on public transportation is affecting not just you, but also your peers who are already financially strained.
# --------------------------------------------------
# Event 3:
#   ID: evt218539321694211805109175156887094223491
#   Agent ID: ag72985641734958267
#   Timeline: L2
#   Description: You are preparing for your UPSC exams when you receive a notification from your local transport authority that the new tax on public transportation will be used to fund education for underprivileged children, and you feel a sense of pride and purpose in contributing to the betterment of your community.
# --------------------------------------------------
# Event 4:
#   ID: evt117870812607899264059741403537904289286
#   Agent ID: ag61758493627581946
#   Timeline: L2
#   Description: You are discussing the new tax on public transportation with your colleagues at the college when one of them mentions that the increased revenue from the tax will be used to improve the public transportation system, making it more efficient and reliable, and you start to think about the potential long-term benefits of the policy.
# --------------------------------------------------
# Event 5:
#   ID: evt11763439767466136108136304141457244781
#   Agent ID: ag72985641734958267
#   Timeline: L1
#   Description: You are traveling to your village for a family gathering when you notice that the new tax on public transportation has made it harder for people from lower-income backgrounds to afford transportation, and you realize that the policy may have unintended consequences on the most vulnerable members of your community.
# --------------------------------------------------
# Event 6:
#   ID: evt208950379629625478127828142667028879898
#   Agent ID: ag54638927165482935
#   Timeline: L2
#   Description: You are reading an article about the new tax on public transportation when you come across a statement from a government official saying that the revenue generated from the tax will be used to fund initiatives that promote education and social welfare, and you start to think about the potential positive impact of the policy on your community.
# --------------------------------------------------
# Event 7:
#   ID: evt193875756192238460072912238854085076443
#   Agent ID: ag61758493627581946
#   Timeline: L1
#   Description: You are attending a community meeting where people are discussing the impact of the new tax on public transportation on their daily lives, and you realize that the policy has created a sense of uncertainty and anxiety among the community, with some people feeling that the tax is unfair and others seeing it as a necessary measure to fund important social programs.
# --------------------------------------------------

# %%
reactions = generate_base_reactions(events=eventlist, llm=llm)

# %%
for i, r in enumerate(reactions, 1):
    print(f"--- Reaction {i} ---")
    print(f"Event ID : {r['event_id']}")
    print(f"Agent ID : {r['agent_id']}")
    print(f"Reaction : {r['base_reaction']}")
    print()
# Out:
# --- Reaction 1 ---
# Event ID : evt74643243171570525156980358881620568921
# Agent ID : ag61758493627581946
# Reaction : The new tax on public transportation, it is indeed a needful measure, I suppose, to ensure the systematic upkeep of our buses, but really, a 10% increase is quite steep, isn't it? As a responsible citizen and a guardian to my students, I must consider the respective impact on our collective finances, and I do worry about the burden it will place on my own budget, but I am willing to make the necessary adjustments for the greater good. After all, as a nation, we must prioritize our infrastructure and abide by the decisions of our government, which, like a wise parent, knows what is best for us. I just hope the authorities will also consider the plight of the common man and provide needful subsidies or alternatives to mitigate the effects of this tax hike.
#
# --- Reaction 2 ---
# Event ID : evt140008574488538235800073781618434139903
# Agent ID : ag54638927165482935
# Reaction : "Yeh kya ho raha hai, yaar? The recent tax on public transportation is a regressive policy that disproportionately affects the already vulnerable sections of our society, including students like my friend who are struggling to make ends meet. As someone who has studied the Indian Constitution, I am reminded of the directive principles of state policy, particularly Article 41, which emphasizes the state's duty to provide public assistance in cases of unemployment, old age, sickness, and disability - and I firmly believe that affordable education and transportation are fundamental rights that the state must protect. It's high time we question the government's priorities and demand a more progressive taxation system that doesn't burden the common man."
#
# --- Reaction 3 ---
# Event ID : evt218539321694211805109175156887094223491
# Agent ID : ag72985641734958267
# Reaction : "Bahut accha decision hai, sir, ki public transportation ke tax se underprivileged bachchon ki education ho rahi hai, yeh to ek bahut bada step hai towards socio-economic equality, aur mujhe garv hai ki main bhi ismein apna yogdan de raha hoon. Maine apne gaon mein dekha hai ki kai bacche school nahin ja paate kyunki unke paas paise nahin hote, lekin ab yeh tax humein unki madad karne ka mauka dega. Yeh to ek achhi shuruaat hai, lekin mujhe lagta hai ki implementation level par bahut dhyan dena hoga, nahi to yeh bhi ek wahi scheme ban kar rahe jayegi. Phir bhi, mujhe ummeed hai ki yeh decision humari community ko ek naye disha mein le jayega, aur main ismein apna yogdan dena chahta hoon."
#
# --- Reaction 4 ---
# Event ID : evt117870812607899264059741403537904289286
# Agent ID : ag61758493627581946
# Reaction : The new tax on public transportation, it's a needful step, I must say, as it will ultimately lead to a more efficient and reliable system, which is the respective responsibility of our government to provide. As an educator, I always emphasize the importance of patience and long-term vision to my students, and I believe this policy is a systematic approach to improving our infrastructure. It's our moral duty to support such initiatives, even if it means a slight increase in our daily expenses, as it will benefit the greater good in the long run. By doing so, we are not only fulfilling our obligation to the state but also setting a good example for our youngsters to follow, in terms of civic responsibility and self-reliance.
#
# --- Reaction 5 ---
# Event ID : evt11763439767466136108136304141457244781
# Agent ID : ag72985641734958267
# Reaction : Arre, yeh tax ka decision toh garib logon ke liye bahut mushkil kar dega, I am thinking, because in my village, so many people are totally dependent on public transport, and now they have to pay more, it is like, socio-economic inequality increase ho jayega. Maine socha tha ki Delhi's vision is to help people, lekin sometimes I feel ki 'System' ke andar itna corruption hai ki actual implementation mein sab kuch ulta ho jata hai. Mujhe lagta hai ki policymakers ko Panchayat level par logon ki problems samajhne ki zaroorat hai, tabhi toh we can build a better nation, na?
#
# --- Reaction 6 ---
# Event ID : evt208950379629625478127828142667028879898
# Agent ID : ag54638927165482935
# Reaction : The introduction of a tax on public transportation, ostensibly to fund education and social welfare initiatives, raises intriguing questions about the government's priorities and the potential redistributive effects on our middle-class community. As someone who has witnessed the struggles of my own family in accessing quality education, I am inclined to view this policy through the lens of Article 21 of the Constitution, which guarantees the right to education - but I must also consider the regressive nature of such a tax, which may disproportionately burden the marginalized sections of our society. The government's assertion that the revenue will be utilized for benevolent purposes is laudable, yet I remain skeptical, given the historical precedents of such levies being used to further entrench existing power dynamics. Can we truly trust that the allocation of these funds will be guided by the principles of social justice and equality enshrined in our Constitution?
#
# --- Reaction 7 ---
# Event ID : evt193875756192238460072912238854085076443
# Agent ID : ag61758493627581946
# Reaction : The introduction of this new tax on public transportation has indeed created a sense of unease amongst our community, and as a responsible citizen, I believe it is our duty to respect the government's decision and give it a fair chance to prove its needful benefits. As an educator, I always emphasize the importance of systematic planning and the respective sacrifices we must make for the greater good, and I firmly believe that this policy, though initially challenging, will ultimately benefit our society in the long run. We must have faith in our government's intentions and understand that such measures are necessary to fund important social programs that cater to the less fortunate, thereby promoting a more equitable distribution of resources. By being obedient and cooperative, we can ensure a smooth implementation of this policy and contribute to the overall well-being of our community.
